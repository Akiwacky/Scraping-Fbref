# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
goalkeeper_url = "https://fbref.com/en/comps/Big5/keepers/players/Big-5-European-Leagues-Stats"
adv_goalkeeper_url = "https://fbref.com/en/comps/Big5/keepersadv/players/Big-5-European-Leagues-Stats"
passing_url = "https://fbref.com/en/comps/Big5/passing/players/Big-5-European-Leagues-Stats"
defense_url = "https://fbref.com/en/comps/Big5/defense/players/Big-5-European-Leagues-Stats"
playing_time_url = "https://fbref.com/en/comps/Big5/playingtime/players/Big-5-European-Leagues-Stats"
possession_url = "https://fbref.com/en/comps/Big5/possession/players/Big-5-European-Leagues-Stats"
misc_url = "https://fbref.com/en/comps/Big5/misc/players/Big-5-European-Leagues-Stats"

# %%
link = 'https://fbref.com/en/comps/Big5/shooting/players/Big-5-European-Leagues-Statss'

# %%
url_link = link

# %%
df = pd.read_html(adv_goalkeeper_url)[0]
df
# Out:
#     Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk                Player             Nation
# 0                    1               Alisson             br BRA
# 1                    2       Alphonse Areola             fr FRA
# 2                    3     Kepa Arrizabalaga             es ESP
# 3                    4          Noah Atubolu             de GER
# 4                    5           Emil Audero             it ITA
# ..                 ...                   ...                ...
# 178                173           Iván Villar             es ESP
# 179                174  Odisseas Vlachodimos             gr GRE
# 180                175         Robin Zentner             de GER
# 181                 Rk                Player             Nation
# 182                176      Michael Zetterer             de GER
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                    Pos              Squad                Comp
# ...

# %%
df.columns = df.columns.get_level_values(1)

# %%
df
# Out:
#       Rk                Player  Nation  Pos            Squad  \
# 0      1               Alisson  br BRA   GK        Liverpool
# 1      2       Alphonse Areola  fr FRA   GK         West Ham
# 2      3     Kepa Arrizabalaga  es ESP   GK      Real Madrid
# 3      4          Noah Atubolu  de GER   GK         Freiburg
# 4      5           Emil Audero  it ITA   GK            Inter
# ..   ...                   ...     ...  ...              ...
# 178  173           Iván Villar  es ESP   GK       Celta Vigo
# 179  174  Odisseas Vlachodimos  gr GRE   GK  Nott'ham Forest
# 180  175         Robin Zentner  de GER   GK         Mainz 05
# 181   Rk                Player  Nation  Pos            Squad
# 182  176      Michael Zetterer  de GER   GK    Werder Bremen
#
#                    Comp     Age  Born   90s  GA  ...  Att  Launch%  AvgLen  \
# 0    eng Premier League  31-179  1992  21.0  19  ...  103     36.9    34.6
# 1    eng Premier League  31-031  1993  25.5  41  ...  187     65.8    46.4
# ...

# %%
csv_name = "23_24_adv_goalkeeping_stats"

# %%
df.to_csv(f'/content/drive/MyDrive/data/{csv_name}', index=False)
